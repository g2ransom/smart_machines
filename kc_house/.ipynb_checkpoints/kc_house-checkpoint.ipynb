# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV, KFold, cross_val_score
from sklearn.linear_model import HuberRegressor, Lars, Lasso, LinearRegression, Ridge
# %matplotlib inline
plt.style.use('ggplot')

# %%
kc = pd.read_csv('../datasets/kc_house.csv', 
                 usecols = lambda col: col not in ['id', 'date', 'yr_built', 
                                                   'yr_renovated', 'zipcode',
                                                  'waterfront', 'view'])

# %%
kc.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  condition  \
# 0  221900.0         3       1.00         1180      5650     1.0          3
# 1  538000.0         3       2.25         2570      7242     2.0          3
# 2  180000.0         2       1.00          770     10000     1.0          3
# 3  604000.0         4       3.00         1960      5000     1.0          5
# 4  510000.0         3       2.00         1680      8080     1.0          3
#
#    grade  sqft_above  sqft_basement      lat     long  sqft_living15  \
# 0      7        1180              0  47.5112 -122.257           1340
# 1      7        2170            400  47.7210 -122.319           1690
# 2      6         770              0  47.7379 -122.233           2720
# 3      7        1050            910  47.5208 -122.393           1360
# 4      8        1680              0  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503

# %%
X = kc.drop(['price'], axis=1)
y = kc.price

# %%
scaler = StandardScaler()
X = scaler.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                    test_size=0.2, random_state=0)

# %%
ridge = Ridge()
param_grid = {'alpha': [0.1, 1, 10, 100, 1000]}
grid_ridge = GridSearchCV(estimator=ridge, param_grid=param_grid)
grid_ridge.fit(X_train, y_train)
print(grid_ridge.best_score_, grid_ridge.best_params_)
# Out:
# (0.6273691342509674, {'alpha': 100})

# %%
ridge1 = Ridge(alpha=100)
ridge1.fit(X_train, y_train)
pred = ridge1.predict(X_test)

# %%
sklearn.metrics.r2_score(y_test, pred)
# Out:
# 0.6372255417664359

# %%
lasso = Lasso()
grid_lasso = GridSearchCV(estimator=lasso, param_grid=param_grid)
grid_lasso.fit(X_train, y_train)
print(grid_lasso.best_score_, grid_lasso.best_params_)
# Out:
# /Users/garrettransom/smart_machines/env/lib/python2.7/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/garrettransom/smart_machines/env/lib/python2.7/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/garrettransom/smart_machines/env/lib/python2.7/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# ...

# %%
lasso1 = Lasso(alpha=100)
lasso1.fit(X_train, y_train)
predl = lasso1.predict(X_test)

# %%
sklearn.metrics.r2_score(y_test, predl)
# Out:
# 0.6370531155409814

# %%
kc.columns
# Out:
# Index([u'price', u'bedrooms', u'bathrooms', u'sqft_living', u'sqft_lot',
#        u'floors', u'condition', u'grade', u'sqft_above', u'sqft_basement',
#        u'lat', u'long', u'sqft_living15', u'sqft_lot15'],
#       dtype='object')

# %%
kc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 14 columns):
# price            21613 non-null float64
# bedrooms         21613 non-null int64
# bathrooms        21613 non-null float64
# sqft_living      21613 non-null int64
# sqft_lot         21613 non-null int64
# floors           21613 non-null float64
# condition        21613 non-null int64
# grade            21613 non-null int64
# sqft_above       21613 non-null int64
# sqft_basement    21613 non-null int64
# lat              21613 non-null float64
# long             21613 non-null float64
# sqft_living15    21613 non-null int64
# sqft_lot15       21613 non-null int64
# dtypes: float64(5), int64(9)
# memory usage: 2.3 MB

# %%
kc.describe()
# Out:
#               price      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  2.161300e+04
# mean   5.400881e+05      3.370842      2.114757   2079.899736  1.510697e+04
# std    3.671272e+05      0.930062      0.770163    918.440897  4.142051e+04
# min    7.500000e+04      0.000000      0.000000    290.000000  5.200000e+02
# 25%    3.219500e+05      3.000000      1.750000   1427.000000  5.040000e+03
# 50%    4.500000e+05      3.000000      2.250000   1910.000000  7.618000e+03
# 75%    6.450000e+05      4.000000      2.500000   2550.000000  1.068800e+04
# max    7.700000e+06     33.000000      8.000000  13540.000000  1.651359e+06
#
#              floors     condition         grade    sqft_above  sqft_basement  \
# count  21613.000000  21613.000000  21613.000000  21613.000000   21613.000000
# mean       1.494309      3.409430      7.656873   1788.390691     291.509045
# ...

# %%
corr = kc.corr()
fig, ax = plt.subplots(figsize=(15, 10))
ax.xaxis.tick_top()
sns.heatmap(corr, xticklabels= corr.columns, yticklabels = corr.columns, annot=True)

# %%
kc.condition.hist()

# %%
kc.grade.hist(bins=10)

# %%
kc.sqft_living15.hist(bins=100)

# %%
kc.sqft_lot15.hist(bins=100)

# %%
kc.sqft_lot.hist(bins=100)

# %%
sns.scatterplot(x='sqft_lot15', y='sqft_lot', data=kc)
